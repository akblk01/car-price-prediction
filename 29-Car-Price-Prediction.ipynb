# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn
import tensorflow as tf

# %%
dataFrame = pd.read_excel("merc.xlsx")

# %%
dataFrame.head()
# Out:
#    year  price transmission  mileage  tax   mpg  engineSize
# 0  2005   5200    Automatic    63000  325  32.1         1.8
# 1  2017  34948    Automatic    27000   20  61.4         2.1
# 2  2016  49948    Automatic     6200  555  28.0         5.5
# 3  2016  61948    Automatic    16000  325  30.4         4.0
# 4  2016  73948    Automatic     4000  325  30.1         4.0

# %%
dataFrame.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  13119.000000   13119.000000   13119.000000  13119.000000  13119.000000
# mean    2017.296288   24698.596920   21949.559037    129.972178     55.155843
# std        2.224709   11842.675542   21176.512267     65.260286     15.220082
# min     1970.000000     650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000   17450.000000    6097.500000    125.000000     45.600000
# 50%     2018.000000   22480.000000   15189.000000    145.000000     56.500000
# 75%     2019.000000   28980.000000   31779.500000    145.000000     64.200000
# max     2020.000000  159999.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  13119.000000
# mean       2.071530
# std        0.572426
# min        0.000000
# 25%        1.800000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
dataFrame.isnull().sum() # colonlarda boş veri var mı ?
# Out:
# year            0
# price           0
# transmission    0
# mileage         0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
sbn.displot(dataFrame["price"])

# %% [markdown]
# ## Grafikte uç değerler çok olduğunu anlamak için grafik çiziyoruz

# %%
sbn.countplot(dataFrame["year"])
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year', ylabel='count'>

# %%
dataFrame.corr()
# Out:
#                 year     price   mileage       tax       mpg  engineSize
# year        1.000000  0.520712 -0.738027  0.012480 -0.094626   -0.142147
# price       0.520712  1.000000 -0.537214  0.268717 -0.438445    0.516126
# mileage    -0.738027 -0.537214  1.000000 -0.160223  0.202850    0.063652
# tax         0.012480  0.268717 -0.160223  1.000000 -0.513742    0.338341
# mpg        -0.094626 -0.438445  0.202850 -0.513742  1.000000   -0.339862
# engineSize -0.142147  0.516126  0.063652  0.338341 -0.339862    1.000000

# %%
dataFrame.corr()["price"].sort_values()
# Out:
# mileage      -0.537214
# mpg          -0.438445
# tax           0.268717
# engineSize    0.516126
# year          0.520712
# price         1.000000
# Name: price, dtype: float64

# %%
sbn.scatterplot(x="mileage",y="price",data=dataFrame)
# Out:
# <AxesSubplot:xlabel='mileage', ylabel='price'>

# %%
dataFrame.sort_values("price", ascending = False).head(20)
# Out:
#        year   price transmission  mileage  tax   mpg  engineSize
# 6199   2020  159999    Semi-Auto     1350  145  21.4         4.0
# 10044  2020  154998    Automatic     3000  150  21.4         4.0
# 5      2011  149948    Automatic     3000  570  21.4         6.2
# 8737   2019  140319    Semi-Auto      785  150  22.1         4.0
# 6386   2018  139995    Semi-Auto    13046  145  21.4         4.0
# 8      2019  139948    Automatic    12000  145  21.4         4.0
# 9133   2019  139559    Semi-Auto     1000  145  22.1         4.0
# 8821   2020  138439    Semi-Auto     1000  145  22.1         4.0
# 5902   2018  135771    Semi-Auto    19000  145  21.4         4.0
# 7864   2018  135124    Semi-Auto    18234  150  21.4         4.0
# 8673   2019  134219    Semi-Auto     1000  145  24.8         4.0
# 6210   2019  129990    Automatic     1000  145  24.8         4.0
# 4759   2019  126000    Automatic      250  145  24.6         4.0
# ...

# %%
dataFrame.sort_values("price", ascending = True).head(20)
# Out:
#        year  price transmission  mileage  tax   mpg  engineSize
# 11816  2003    650       Manual   109090  235  40.0         1.4
# 12008  2010   1350       Manual   116126  145  54.3         2.0
# 11765  2000   1490    Automatic    87000  265  27.2         3.2
# 11549  2002   1495    Automatic    13800  305  39.8         2.7
# 12594  2004   1495       Manual   119000  300  34.5         1.8
# 11174  2001   1695    Automatic   108800  325  31.7         3.2
# 12710  2006   1695    Automatic   153000  300  33.6         1.8
# 12766  2004   1780    Automatic   118000  265  41.5         2.2
# 12009  2007   1800    Automatic    84000  200  42.8         1.5
# 11764  1998   1990    Automatic    99300  265  32.1         2.3
# 11808  1998   1990    Automatic   113557  265  32.1         2.3
# 11383  2005   1995    Automatic   105000  260  43.5         2.1
# 11378  2004   1995    Semi-Auto   165000  330  20.0         3.7
# 11857  2002   2140    Automatic    52700  325  31.4         2.0
# ...

# %%
temizDf = dataFrame.sort_values("price", ascending = False).iloc[131:]

# %% [markdown]
# ## Veri setinde uç değerleri atabilmek için genel yapılan şey verinin oransal olarak büyük kısmının %1'i atılır

# %%
sbn.displot(temizDf["price"])

# %% [markdown]
# ## Grafiğin dağılımı şuan daha iyi. Bu tamamen kendi kararımız. İki veri seti içinde ayrı ayrı model oluşturabilirdik.

# %%
temizDf.groupby("year").mean()["price"]
# Out:
# year
# 1970    24999.000000
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011     8913.459459
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16647.822222
# 2016    19223.558943
# 2017    21356.280421
# 2018    24800.844506
# 2019    30289.524832
# 2020    34234.794872
# Name: price, dtype: float64

# %% [markdown]
# ## Burada görüleceği üzere 70 model bir arabanın 25k pound olduğunu anlıyoruz. Bu veri setimizin genel sunduğu ortalamayı bozduğu için bu veriyi çıkartıyoruz. Ama yine tamamen nasıl çalışmak istediğimiz ile alakalı.

# %%
 dataFrame = temizDf

# %%
dataFrame = dataFrame[dataFrame.year != 1970]

# %%
dataFrame.groupby("year").mean()["price"]
# Out:
# year
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011     8913.459459
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16647.822222
# 2016    19223.558943
# 2017    21356.280421
# 2018    24800.844506
# 2019    30289.524832
# 2020    34234.794872
# Name: price, dtype: float64

# %%
dataFrame = dataFrame.drop("transmission", axis = 1 )

# %%
dataFrame.head()
# Out:
#       year  price  mileage  tax   mpg  engineSize
# 6177  2019  65990     5076  150  30.4         3.0
# 5779  2020  65990      999  145  28.0         4.0
# 3191  2020  65980     3999  145  28.0         4.0
# 4727  2019  65000     3398  145  27.2         4.0
# 8814  2019  64999      119  145  40.9         3.0

# %%
y = dataFrame["price"].values
x = dataFrame.drop("price", axis = 1).values

# %%
y
# Out:
# array([65990, 65990, 65980, ...,  1490,  1350,   650], dtype=int64)

# %%
x
# Out:
# array([[2.01900e+03, 5.07600e+03, 1.50000e+02, 3.04000e+01, 3.00000e+00],
#        [2.02000e+03, 9.99000e+02, 1.45000e+02, 2.80000e+01, 4.00000e+00],
#        [2.02000e+03, 3.99900e+03, 1.45000e+02, 2.80000e+01, 4.00000e+00],
#        ...,
#        [2.00000e+03, 8.70000e+04, 2.65000e+02, 2.72000e+01, 3.20000e+00],
#        [2.01000e+03, 1.16126e+05, 1.45000e+02, 5.43000e+01, 2.00000e+00],
#        [2.00300e+03, 1.09090e+05, 2.35000e+02, 4.00000e+01, 1.40000e+00]])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 25)

# %%
len(x_train)
# Out:
# 9090

# %%
len(x_test)
# Out:
# 3897

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_test = scaler.fit_transform(x_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(17, activation = "relu"))
model.add(Dense(17, activation = "relu"))
model.add(Dense(17, activation = "relu"))
model.add(Dense(17, activation = "relu"))

model.add(Dense(1))

model.compile(optimizer = "adam", loss = "mse")

# %%
model.fit(x = x_train, y = y_train, validation_data = (x_test, y_test), batch_size = 250, epochs=300)
# Out:
# Epoch 1/300
# 37/37 [==============================] - 1s 5ms/step - loss: 670236544.0000 - val_loss: 692516928.0000
# Epoch 2/300
# 37/37 [==============================] - 0s 2ms/step - loss: 670173312.0000 - val_loss: 692381824.0000
# Epoch 3/300
# 37/37 [==============================] - 0s 2ms/step - loss: 669895808.0000 - val_loss: 691854976.0000
# Epoch 4/300
# 37/37 [==============================] - 0s 2ms/step - loss: 668893440.0000 - val_loss: 690019968.0000
# Epoch 5/300
# 37/37 [==============================] - 0s 2ms/step - loss: 665770240.0000 - val_loss: 684705792.0000
# Epoch 6/300
# 37/37 [==============================] - 0s 2ms/step - loss: 657464448.0000 - val_loss: 671587648.0000
# Epoch 7/300
# 37/37 [==============================] - 0s 3ms/step - loss: 638620416.0000 - val_loss: 643253056.0000
# Epoch 8/300
# 37/37 [==============================] - 0s 2ms/step - loss: 600091008.0000 - val_loss: 588523776.0000
# Epoch 9/300
# ...

# %%
lossData = pd.DataFrame(model.history.history)

# %%
lossData.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Bu grafikte önemli olan iki eğirinin birbiriyle aynı ölçüde grafikte hareket etmeleri ve sıfıra yaklaşmaları

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
tahminDizisi = model.predict(x_test)

# %%
tahminDizisi
# Out:
# array([[20982.55 ],
#        [24119.96 ],
#        [25949.156],
#        ...,
#        [11113.585],
#        [22424.46 ],
#        [17340.184]], dtype=float32)

# %%
mean_absolute_error(y_test, tahminDizisi)
# Out:
# 3449.528721058341

# %%
dataFrame.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  12987.000000  12987.000000   12987.000000  12987.000000  12987.000000
# mean    2017.285516  24074.855779   22133.367367    129.676215     55.438392
# std        2.189633   9866.601115   21197.472376     65.167429     15.025902
# min     1997.000000    650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000  17355.000000    6320.000000    125.000000     45.600000
# 50%     2018.000000  22299.000000   15371.000000    145.000000     56.500000
# 75%     2019.000000  28706.000000   31986.500000    145.000000     64.200000
# max     2020.000000  65990.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  12987.000000
# mean       2.051059
# std        0.532313
# min        0.000000
# 25%        1.700000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %% [markdown]
# ## absolut_error skoruna göre hata oranınımız %14. Bu yaptığımız çalışmanın hassaslığına göre optimize edilebilir.

# %%
plt.scatter(y_test,tahminDizisi)
plt.plot(y_test, y_test, "g")
